# %%
#strings
a = "Hello, World!"
print(len(a))
print(a.strip())
print(a.lower())
print(a.upper())
print(a.replace("H", "J"))
print(a.split(","))
#list
thislist = ["apple", "banana", "cherry"]
print(thislist)
print(thislist[-1])
thislist[1] = "blackcurrant"
print(thislist)
print(len(thislist))
thislist.append("orange")
print(thislist)
thislist.insert(1, "chickoo")
print(thislist)
thislist.remove("cherry")
print(thislist)
del thislist[0]
print(thislist)
mylist = thislist.copy()
print(mylist)
#tuples
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[-4:-1])
print(len(thistuple))
tuple2 = (1, 2, 3)
tuple3 = thistuple+ tuple2
print(tuple3)
x=tuple3.count("apple")
print(x)
print(tuple3.index("kiwi"))
#sets
thisset = {"apple", "banana", "cherry"}
print(thisset)
thisset.add("orange")
print(thisset)
thisset.update(["orange", "mango", "grapes"])
print(thisset)
print(len(thisset))
thisset.remove("banana")
print(thisset)
thisset.discard("mango")
print(thisset)
thisset.clear()
print(thisset)
set2 = {1, 2, 3}
set1={4,5,6,3,2}
set3 = set1.union(set2)
print(set3)
set1.difference(set2)
#dictionary
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict.get("model")
print(len(thisdict))
thisdict["color"] = "red"
print(thisdict)
thisdict.pop("model")
print(thisdict)
mydict = thisdict.copy()
print(mydict)
mydict = dict(thisdict)
print(mydict)
# Out:
# 13
# Hello, World!
# hello, world!
# HELLO, WORLD!
# Jello, World!
# ['Hello', ' World!']
# ['apple', 'banana', 'cherry']
# cherry
# ['apple', 'blackcurrant', 'cherry']
# 3
# ['apple', 'blackcurrant', 'cherry', 'orange']
# ['apple', 'chickoo', 'blackcurrant', 'cherry', 'orange']
# ['apple', 'chickoo', 'blackcurrant', 'orange']
# ['chickoo', 'blackcurrant', 'orange']
# ['chickoo', 'blackcurrant', 'orange']
# ('orange', 'kiwi', 'melon')
# 7
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 1, 2, 3)
# 1
# 4
# {'banana', 'cherry', 'apple'}
# {'banana', 'orange', 'cherry', 'apple'}
# {'banana', 'orange', 'cherry', 'apple', 'grapes', 'mango'}
# 6
# {'orange', 'cherry', 'apple', 'grapes', 'mango'}
# {'orange', 'cherry', 'apple', 'grapes'}
# set()
# {1, 2, 3, 4, 5, 6}
# 3
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}
# {'brand': 'Ford', 'year': 1964, 'color': 'red'}
# {'brand': 'Ford', 'year': 1964, 'color': 'red'}
# {'brand': 'Ford', 'year': 1964, 'color': 'red'}
